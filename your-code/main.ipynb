# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
from functools import reduce
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')

# %%
len(prophet)
# Out:
# 13637

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# your code here
prophet=prophet[569:]
prophet
# Out:
# ['the{7}',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto',
#  'his',
#  'own\nday,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'in',
#  'the',
#  'city\nof',
#  'Orphalese',
#  'for',
#  'his',
#  'ship',
#  'that',
#  'was',
#  'to\nreturn',
#  'and',
#  'bear',
#  'him',
#  'back',
#  'to',
#  'the',
#  'isle',
#  'of\nhis',
#  'birth.\n\nAnd',
#  'in',
#  'the',
#  'twelfth',
#  'year,',
#  'on',
#  'the',
#  'seventh\nday',
#  'of',
#  'Ielool,',
#  'the',
#  'month',
#  'of',
#  'reaping,',
#  'he\nclimbed',
#  'the',
#  'hill',
#  'without',
#  'the',
#  'city',
#  'walls\nand',
#  'looked',
#  'seaward;',
#  'and',
#  'he',
#  'beheld',
#  'his\nship',
#  'coming',
#  'with',
#  'the',
#  'mist.\n\nThen',
#  'the',
#  'gates',
#  'of',
#  'his',
#  'heart',
#  'were',
#  'flung\nopen,',
#  'and',
#  'his',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'the',
#  'sea.\nAnd',
#  'he',
#  'closed',
#  'his',
#  'eyes',
#  'and',
#  'prayed',
#  'in',
#  'the\nsilences',
#  'of',
#  'his',
#  'soul.\n\n*****\n\nBut',
#  'as',
#  'he',
#  'descended',
#  'the',
#  'hill,',
#  'a',
#  'sadness\ncame',
#  'upon',
#  'him,',
#  'and',
#  'he',
#  'thought',
#  'in',
#  'his\nheart:\n\nHow',
#  'shall',
#  'I',
#  'go',
#  'in',
#  'peace',
#  'and',
#  'without\nsorrow?',
#  'Nay,',
#  'not',
#  'without',
#  'a',
#  'wound',
#  'in',
#  'the\nspirit',
#  'shall',
#  'I',
#  'leave',
#  'this',
#  'city.',
#  '{8}Long\nwere',
#  'the',
#  'days',
#  'of',
#  'pain',
#  'I',
#  'have',
#  'spent\nwithin',
#  'its',
#  'walls,',
#  'and',
#  'long',
#  'were',
#  'the\nnights',
#  'of',
#  'aloneness;',
#  'and',
#  'who',
#  'can',
#  'depart\nfrom',
#  'his',
#  'pain',
#  'and',
#  'his',
#  'aloneness',
#  'without\nregret?\n\nToo',
#  'many',
#  'fragments',
#  'of',
#  'the',
#  'spirit',
#  'have',
#  'I\nscattered',
#  'in',
#  'these',
#  'streets,',
#  'and',
#  'too',
#  'many\nare',
#  'the',
#  'children',
#  'of',
#  'my',
#  'longing',
#  'that',
#  'walk\nnaked',
#  'among',
#  'these',
#  'hills,',
#  'and',
#  'I',
#  'cannot\nwithdraw',
#  'from',
#  'them',
#  'without',
#  'a',
#  'burden',
#  'and\nan',
#  'ache.\n\nIt',
#  'is',
#  'not',
#  'a',
#  'garment',
#  'I',
#  'cast',
#  'off',
#  'this\nday,',
#  'but',
#  'a',
#  'skin',
#  'that',
#  'I',
#  'tear',
#  'with',
#  'my',
#  'own\nhands.\n\nNor',
#  'is',
#  'it',
#  'a',
#  'thought',
#  'I',
#  'leave',
#  'behind',
#  'me,\nbut',
#  'a',
#  'heart',
#  'made',
#  'sweet',
#  'with',
#  'hunger',
#  'and\nwith',
#  'thirst.\n\n*****\n\nYet',
#  'I',
#  'cannot',
#  'tarry',
#  'longer.\n\nThe',
#  'sea',
#  'that',
#  'calls',
#  'all',
#  'things',
#  'unto',
#  'her\ncalls',
#  'me,',
#  'and',
#  'I',
#  'must',
#  'embark.\n\nFor',
#  'to',
#  'stay,',
#  'though',
#  'the',
#  'hours',
#  'burn',
#  'in\nthe',
#  'night,',
#  'is',
#  'to',
#  'freeze',
#  'and',
#  'crystallize\nand',
#  'be',
#  'bound',
#  'in',
#  'a',
#  'mould.\n\nFain',
#  'would',
#  'I',
#  'take',
#  'with',
#  'me',
#  'all',
#  'that',
#  'is\nhere.',
#  'But',
#  'how',
#  'shall',
#  'I?\n\nA',
#  'voice',
#  'cannot',
#  'carry',
#  'the',
#  'tongue',
#  'and\n{9}the',
#  'lips',
#  'that',
#  'gave',
#  'it',
#  'wings.',
#  'Alone\nmust',
#  'it',
#  'seek',
#  'the',
#  'ether.\n\nAnd',
#  'alone',
#  'and',
#  'without',
#  'his',
#  'nest',
#  'shall',
#  'the\neagle',
#  'fly',
#  'across',
#  'the',
#  'sun.\n\n*****\n\nNow',
#  'when',
#  'he',
#  'reached',
#  'the',
#  'foot',
#  'of',
#  'the\nhill,',
#  'he',
#  'turned',
#  'again',
#  'towards',
#  'the',
#  'sea,\nand',
#  'he',
#  'saw',
#  'his',
#  'ship',
#  'approaching',
#  'the\nharbour,',
#  'and',
#  'upon',
#  'her',
#  'prow',
#  'the',
#  'mariners,\nthe',
#  'men',
#  'of',
#  'his',
#  'own',
#  'land.\n\nAnd',
#  'his',
#  'soul',
#  'cried',
#  'out',
#  'to',
#  'them,',
#  'and',
#  'he\nsaid:\n\nSons',
#  'of',
#  'my',
#  'ancient',
#  'mother,',
#  'you',
#  'riders',
#  'of\nthe',
#  'tides,\n\nHow',
#  'often',
#  'have',
#  'you',
#  'sailed',
#  'in',
#  'my',
#  'dreams.\nAnd',
#  'now',
#  'you',
#  'come',
#  'in',
#  'my',
#  'awakening,',
#  'which\nis',
#  'my',
#  'deeper',
#  'dream.\n\nReady',
#  'am',
#  'I',
#  'to',
#  'go,',
#  'and',
#  'my',
#  'eagerness',
#  'with\nsails',
#  'full',
#  'set',
#  'awaits',
#  'the',
#  'wind.\n\nOnly',
#  'another',
#  'breath',
#  'will',
#  'I',
#  'breathe',
#  'in\nthis',
#  'still',
#  'air,',
#  'only',
#  'another',
#  'loving',
#  'look\ncast',
#  'backward,\n\nAnd',
#  'then',
#  'I',
#  'shall',
#  'stand',
#  'among',
#  'you,',
#  'a\nseafarer',
#  'among',
#  'seafarers.',
#  '{10}And',
#  'you,\nvast',
#  'sea,',
#  'sleepless',
#  'mother,\n\nWho',
#  'alone',
#  'are',
#  'peace',
#  'and',
#  'freedom',
#  'to',
#  'the\nriver',
#  'and',
#  'the',
#  'stream,\n\nOnly',
#  'another',
#  'winding',
#  'will',
#  'this',
#  'stream\nmake,',
#  'only',
#  'another',
#  'murmur',
#  'in',
#  'this',
#  'glade,\n\nAnd',
#  'then',
#  'shall',
#  'I',
#  'come',
#  'to',
#  'you,',
#  'a\nboundless',
#  'drop',
#  'to',
#  'a',
#  'boundless',
#  'ocean.\n\n*****\n\nAnd',
#  'as',
#  'he',
#  'walked',
#  'he',
#  'saw',
#  'from',
#  'afar',
#  'men\nand',
#  'women',
#  'leaving',
#  'their',
#  'fields',
#  'and',
#  'their\nvineyards',
#  'and',
#  'hastening',
#  'towards',
#  'the',
#  'city\ngates.\n\nAnd',
#  'he',
#  'heard',
#  'their',
#  'voices',
#  'calling',
#  'his\nname,',
#  'and',
#  'shouting',
#  'from',
#  'field',
#  'to',
#  'field\ntelling',
#  'one',
#  'another',
#  'of',
#  'the',
#  'coming',
#  'of',
#  'his\nship.\n\nAnd',
#  'he',
#  'said',
#  'to',
#  'himself:\n\nShall',
#  'the',
#  'day',
#  'of',
#  'parting',
#  'be',
#  'the',
#  'day',
#  'of\ngathering?\n\nAnd',
#  'shall',
#  'it',
#  'be',
#  'said',
#  'that',
#  'my',
#  'eve',
#  'was',
#  'in\ntruth',
#  'my',
#  'dawn?\n\nAnd',
#  'what',
#  'shall',
#  'I',
#  'give',
#  'unto',
#  'him',
#  'who',
#  'has\nleft',
#  'his',
#  'plough',
#  'in',
#  'midfurrow,',
#  'or',
#  'to\nhim',
#  'who',
#  'has',
#  'stopped',
#  'the',
#  'wheel',
#  'of',
#  'his\nwinepress?',
#  '{11}Shall',
#  'my',
#  'heart',
#  'become',
#  'a\ntree',
#  'heavy-laden',
#  'with',
#  'fruit',
#  'that',
#  'I',
#  'may\ngather',
#  'and',
#  'give',
#  'unto',
#  'them?\n\nAnd',
#  'shall',
#  'my',
#  'desires',
#  'flow',
#  'like',
#  'a\nfountain',
#  'that',
#  'I',
#  'may',
#  'fill',
#  'their',
#  'cups?\n\nAm',
#  'I',
#  'a',
#  'harp',
#  'that',
#  'the',
#  'hand',
#  'of',
#  'the',
#  'mighty\nmay',
#  'touch',
#  'me,',
#  'or',
#  'a',
#  'flute',
#  'that',
#  'his',
#  'breath\nmay',
#  'pass',
#  'through',
#  'me?\n\nA',
#  'seeker',
#  'of',
#  'silences',
#  'am',
#  'I,',
#  'and',
#  'what\ntreasure',
#  'have',
#  'I',
#  'found',
#  'in',
#  'silences',
#  'that',
#  'I\nmay',
#  'dispense',
#  'with',
#  'confidence?\n\nIf',
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  'what\nfields',
#  'have',
#  'I',
#  'sowed',
#  'the',
#  'seed,',
#  'and',
#  'in\nwhat',
#  'unremembered',
#  'seasons?\n\nIf',
#  'this',
#  'indeed',
#  'be',
#  'the',
#  'hour',
#  'in',
#  'which',
#  'I\nlift',
#  'up',
#  'my',
#  'lantern,',
#  'it',
#  'is',
#  'not',
#  'my',
#  'flame\nthat',
#  'shall',
#  'burn',
#  'therein.\n\nEmpty',
#  'and',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,\n\nAnd',
#  'the',
#  'guardian',
#  'of',
#  'the',
#  'night',
#  'shall',
#  'fill\nit',
#  'with',
#  'oil',
#  'and',
#  'he',
#  'shall',
#  'light',
#  'it',
#  'also.\n\n*****\n\nThese',
#  'things',
#  'he',
#  'said',
#  'in',
#  'words.',
#  'But',
#  'much\nin',
#  'his',
#  'heart',
#  'remained',
#  'unsaid.',
#  'For',
#  '{12}he\nhimself',
#  'could',
#  'not',
#  'speak',
#  'his',
#  'deeper\nsecret.\n\n*****\n\n[Illustration:',
#  '0020]\n\nAnd',
#  'when',
#  'he',
#  'entered',
#  'into',
#  'the',
#  'city',
#  'all\nthe',
#  'people',
#  'came',
#  'to',
#  'meet',
#  'him,',
#  'and',
#  'they\nwere',
#  'crying',
#  'out',
#  'to',
#  'him',
#  'as',
#  'with',
#  'one\nvoice.\n\nAnd',
#  'the',
#  'elders',
#  'of',
#  'the',
#  'city',
#  'stood',
#  'forth\nand',
#  'said:\n\nGo',
#  'not',
#  'yet',
#  'away',
#  'from',
#  'us.\n\nA',
#  'noontide',
#  'have',
#  'you',
#  'been',
#  'in',
#  'our\ntwilight,',
#  'and',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us\ndreams',
#  'to',
#  'dream.\n\nNo',
#  'stranger',
#  'are',
#  'you',
#  'among',
#  'us,',
#  'nor\na',
#  'guest,',
#  'but',
#  'our',
#  'son',
#  'and',
#  'our',
#  'dearly\nbeloved.\n\nSuffer',
#  'not',
#  'yet',
#  'our',
#  'eyes',
#  'to',
#  'hunger',
#  'for\nyour',
#  'face.\n\n*****\n\nAnd',
#  'the',
#  'priests',
#  'and',
#  'the',
#  'priestesses',
#  'said\nunto',
#  'him:\n\nLet',
#  'not',
#  'the',
#  'waves',
#  'of',
#  'the',
#  'sea',
#  'separate',
#  'us\nnow,',
#  'and',
#  'the',
#  'years',
#  'you',
#  'have',
#  'spent',
#  'in',
#  'our\nmidst',
#  'become',
#  'a',
#  'memory.\n\nYou',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'a',
#  'spirit,\n{13}and',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'a',
#  'light\nupon',
#  'our',
#  'faces.\n\nMuch',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless\nwas',
#  'our',
#  'love,',
#  'and',
#  'with',
#  'veils',
#  'has',
#  'it',
#  'been\nveiled.\n\nYet',
#  'now',
#  'it',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'and\nwould',
#  'stand',
#  'revealed',
#  'before',
#  'you.\n\nAnd',
#  'ever',
#  'has',
#  'it',
#  'been',
#  'that',
#  'love',
#  'knows\nnot',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'the',
#  'hour',
#  'of\nseparation.\n\n*****\n\nAnd',
#  'others',
#  'came',
#  'also',
#  'and',
#  'entreated',
#  'him.\nBut',
#  'he',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent\nhis',
#  'head;',
#  'and',
#  'those',
#  'who',
#  'stood',
#  'near',
#  'saw\nhis',
#  'tears',
#  'falling',
#  'upon',
#  'his',
#  'breast.\n\nAnd',
#  'he',
#  'and',
#  'the',
#  'people',
#  'proceeded',
#  'towards\nthe',
#  'great',
#  'square',
#  'before',
#  'the',
#  'temple.\n\nAnd',
#  'there',
#  'came',
#  'out',
#  'of',
#  'the',
#  'sanctuary',
#  'a\nwoman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she\nwas',
#  'a',
#  'seeress.\n\nAnd',
#  'he',
#  'looked',
#  'upon',
#  'her',
#  'with',
#  'exceeding\ntenderness,',
#  'for',
#  'it',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first\nsought',
#  'and',
#  'believed',
#  'in',
#  'him',
#  'when',
#  'he',
#  'had\nbeen',
#  'but',
#  'a',
#  'day',
#  'in',
#  'their',
#  'city.',
#  '{14}And\nshe',
#  'hailed',
#  'him,',
#  'saying:\n\nProphet',
#  'of',
#  'God,',
#  'in',
#  'quest',
#  'of',
#  'the\nuttermost,',
#  'long',
#  'have',
#  'you',
#  'searched',
#  'the\ndistances',
#  'for',
#  'your',
#  'ship.\n\nAnd',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'and',
#  'you',
#  'must\nneeds',
#  'go.\n\nDeep',
#  'is',
#  'your',
#  'longing',
#  'for',
#  'the',
#  'land',
#  'of\nyour',
#  'memories',
#  'and',
#  'the',
#  'dwelling',
#  'place\nof',
#  'your',
#  'greater',
#  'desires;',
#  'and',
#  'our',
#  'love\nwould',
#  'not',
#  'bind',
#  'you',
#  'nor',
#  'our',
#  'needs',
#  'hold\nyou.\n\nYet',
#  'this',
#  'we',
#  'ask',
#  'ere',
#  'you',
#  'leave',
#  'us,',
#  'that\nyou',
#  'speak',
#  'to',
#  'us',
#  'and',
#  'give',
#  'us',
#  'of',
#  'your\ntruth.\n\nAnd',
#  'we',
#  'will',
#  'give',
#  'it',
#  'unto',
#  'our',
#  'children,\nand',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'and',
#  'it\nshall',
#  'not',
#  'perish.\n\nIn',
#  'your',
#  'aloneness',
#  'you',
#  'have',
#  'watched',
#  'with\nour',
#  'days,',
#  'and',
#  'in',
#  'your',
#  'wakefulness',
#  'you\nhave',
#  'listened',
#  'to',
#  'the',
#  'weeping',
#  'and',
#  'the\nlaughter',
#  'of',
#  'our',
#  'sleep.\n\nNow',
#  'therefore',
#  'disclose',
#  'us',
#  'to',
#  'ourselves,\nand',
#  'tell',
#  'us',
#  'all',
#  'that',
#  'has',
#  'been',
#  'shown\nyou',
#  'of',
#  'that',
#  'which',
#  'is',
#  'between',
#  'birth',
#  'and\ndeath.\n\n*****\n\nAnd',
#  'he',
#  'answered,\n\nPeople',
#  'of',
#  'Orphalese,',
#  'of',
#  ...]

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# your code here
prophet[:10]
# Out:
# ['the{7}',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto',
#  'his']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
    '''
    Input: A string
    Output: The string with references removed
    
    Example:
    Input: 'the{7}'
    Output: 'the'
    '''
    
    # your code here
    if "{" in x:
        return x.split(sep="{")[0]
    else:
        return x

# %%
# your code here

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
# your code here
prophet_reference = list(map(reference,prophet))
prophet_reference
# Out:
# ['the',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto',
#  'his',
#  'own\nday,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'in',
#  'the',
#  'city\nof',
#  'Orphalese',
#  'for',
#  'his',
#  'ship',
#  'that',
#  'was',
#  'to\nreturn',
#  'and',
#  'bear',
#  'him',
#  'back',
#  'to',
#  'the',
#  'isle',
#  'of\nhis',
#  'birth.\n\nAnd',
#  'in',
#  'the',
#  'twelfth',
#  'year,',
#  'on',
#  'the',
#  'seventh\nday',
#  'of',
#  'Ielool,',
#  'the',
#  'month',
#  'of',
#  'reaping,',
#  'he\nclimbed',
#  'the',
#  'hill',
#  'without',
#  'the',
#  'city',
#  'walls\nand',
#  'looked',
#  'seaward;',
#  'and',
#  'he',
#  'beheld',
#  'his\nship',
#  'coming',
#  'with',
#  'the',
#  'mist.\n\nThen',
#  'the',
#  'gates',
#  'of',
#  'his',
#  'heart',
#  'were',
#  'flung\nopen,',
#  'and',
#  'his',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'the',
#  'sea.\nAnd',
#  'he',
#  'closed',
#  'his',
#  'eyes',
#  'and',
#  'prayed',
#  'in',
#  'the\nsilences',
#  'of',
#  'his',
#  'soul.\n\n*****\n\nBut',
#  'as',
#  'he',
#  'descended',
#  'the',
#  'hill,',
#  'a',
#  'sadness\ncame',
#  'upon',
#  'him,',
#  'and',
#  'he',
#  'thought',
#  'in',
#  'his\nheart:\n\nHow',
#  'shall',
#  'I',
#  'go',
#  'in',
#  'peace',
#  'and',
#  'without\nsorrow?',
#  'Nay,',
#  'not',
#  'without',
#  'a',
#  'wound',
#  'in',
#  'the\nspirit',
#  'shall',
#  'I',
#  'leave',
#  'this',
#  'city.',
#  '',
#  'the',
#  'days',
#  'of',
#  'pain',
#  'I',
#  'have',
#  'spent\nwithin',
#  'its',
#  'walls,',
#  'and',
#  'long',
#  'were',
#  'the\nnights',
#  'of',
#  'aloneness;',
#  'and',
#  'who',
#  'can',
#  'depart\nfrom',
#  'his',
#  'pain',
#  'and',
#  'his',
#  'aloneness',
#  'without\nregret?\n\nToo',
#  'many',
#  'fragments',
#  'of',
#  'the',
#  'spirit',
#  'have',
#  'I\nscattered',
#  'in',
#  'these',
#  'streets,',
#  'and',
#  'too',
#  'many\nare',
#  'the',
#  'children',
#  'of',
#  'my',
#  'longing',
#  'that',
#  'walk\nnaked',
#  'among',
#  'these',
#  'hills,',
#  'and',
#  'I',
#  'cannot\nwithdraw',
#  'from',
#  'them',
#  'without',
#  'a',
#  'burden',
#  'and\nan',
#  'ache.\n\nIt',
#  'is',
#  'not',
#  'a',
#  'garment',
#  'I',
#  'cast',
#  'off',
#  'this\nday,',
#  'but',
#  'a',
#  'skin',
#  'that',
#  'I',
#  'tear',
#  'with',
#  'my',
#  'own\nhands.\n\nNor',
#  'is',
#  'it',
#  'a',
#  'thought',
#  'I',
#  'leave',
#  'behind',
#  'me,\nbut',
#  'a',
#  'heart',
#  'made',
#  'sweet',
#  'with',
#  'hunger',
#  'and\nwith',
#  'thirst.\n\n*****\n\nYet',
#  'I',
#  'cannot',
#  'tarry',
#  'longer.\n\nThe',
#  'sea',
#  'that',
#  'calls',
#  'all',
#  'things',
#  'unto',
#  'her\ncalls',
#  'me,',
#  'and',
#  'I',
#  'must',
#  'embark.\n\nFor',
#  'to',
#  'stay,',
#  'though',
#  'the',
#  'hours',
#  'burn',
#  'in\nthe',
#  'night,',
#  'is',
#  'to',
#  'freeze',
#  'and',
#  'crystallize\nand',
#  'be',
#  'bound',
#  'in',
#  'a',
#  'mould.\n\nFain',
#  'would',
#  'I',
#  'take',
#  'with',
#  'me',
#  'all',
#  'that',
#  'is\nhere.',
#  'But',
#  'how',
#  'shall',
#  'I?\n\nA',
#  'voice',
#  'cannot',
#  'carry',
#  'the',
#  'tongue',
#  'and\n',
#  'lips',
#  'that',
#  'gave',
#  'it',
#  'wings.',
#  'Alone\nmust',
#  'it',
#  'seek',
#  'the',
#  'ether.\n\nAnd',
#  'alone',
#  'and',
#  'without',
#  'his',
#  'nest',
#  'shall',
#  'the\neagle',
#  'fly',
#  'across',
#  'the',
#  'sun.\n\n*****\n\nNow',
#  'when',
#  'he',
#  'reached',
#  'the',
#  'foot',
#  'of',
#  'the\nhill,',
#  'he',
#  'turned',
#  'again',
#  'towards',
#  'the',
#  'sea,\nand',
#  'he',
#  'saw',
#  'his',
#  'ship',
#  'approaching',
#  'the\nharbour,',
#  'and',
#  'upon',
#  'her',
#  'prow',
#  'the',
#  'mariners,\nthe',
#  'men',
#  'of',
#  'his',
#  'own',
#  'land.\n\nAnd',
#  'his',
#  'soul',
#  'cried',
#  'out',
#  'to',
#  'them,',
#  'and',
#  'he\nsaid:\n\nSons',
#  'of',
#  'my',
#  'ancient',
#  'mother,',
#  'you',
#  'riders',
#  'of\nthe',
#  'tides,\n\nHow',
#  'often',
#  'have',
#  'you',
#  'sailed',
#  'in',
#  'my',
#  'dreams.\nAnd',
#  'now',
#  'you',
#  'come',
#  'in',
#  'my',
#  'awakening,',
#  'which\nis',
#  'my',
#  'deeper',
#  'dream.\n\nReady',
#  'am',
#  'I',
#  'to',
#  'go,',
#  'and',
#  'my',
#  'eagerness',
#  'with\nsails',
#  'full',
#  'set',
#  'awaits',
#  'the',
#  'wind.\n\nOnly',
#  'another',
#  'breath',
#  'will',
#  'I',
#  'breathe',
#  'in\nthis',
#  'still',
#  'air,',
#  'only',
#  'another',
#  'loving',
#  'look\ncast',
#  'backward,\n\nAnd',
#  'then',
#  'I',
#  'shall',
#  'stand',
#  'among',
#  'you,',
#  'a\nseafarer',
#  'among',
#  'seafarers.',
#  '',
#  'you,\nvast',
#  'sea,',
#  'sleepless',
#  'mother,\n\nWho',
#  'alone',
#  'are',
#  'peace',
#  'and',
#  'freedom',
#  'to',
#  'the\nriver',
#  'and',
#  'the',
#  'stream,\n\nOnly',
#  'another',
#  'winding',
#  'will',
#  'this',
#  'stream\nmake,',
#  'only',
#  'another',
#  'murmur',
#  'in',
#  'this',
#  'glade,\n\nAnd',
#  'then',
#  'shall',
#  'I',
#  'come',
#  'to',
#  'you,',
#  'a\nboundless',
#  'drop',
#  'to',
#  'a',
#  'boundless',
#  'ocean.\n\n*****\n\nAnd',
#  'as',
#  'he',
#  'walked',
#  'he',
#  'saw',
#  'from',
#  'afar',
#  'men\nand',
#  'women',
#  'leaving',
#  'their',
#  'fields',
#  'and',
#  'their\nvineyards',
#  'and',
#  'hastening',
#  'towards',
#  'the',
#  'city\ngates.\n\nAnd',
#  'he',
#  'heard',
#  'their',
#  'voices',
#  'calling',
#  'his\nname,',
#  'and',
#  'shouting',
#  'from',
#  'field',
#  'to',
#  'field\ntelling',
#  'one',
#  'another',
#  'of',
#  'the',
#  'coming',
#  'of',
#  'his\nship.\n\nAnd',
#  'he',
#  'said',
#  'to',
#  'himself:\n\nShall',
#  'the',
#  'day',
#  'of',
#  'parting',
#  'be',
#  'the',
#  'day',
#  'of\ngathering?\n\nAnd',
#  'shall',
#  'it',
#  'be',
#  'said',
#  'that',
#  'my',
#  'eve',
#  'was',
#  'in\ntruth',
#  'my',
#  'dawn?\n\nAnd',
#  'what',
#  'shall',
#  'I',
#  'give',
#  'unto',
#  'him',
#  'who',
#  'has\nleft',
#  'his',
#  'plough',
#  'in',
#  'midfurrow,',
#  'or',
#  'to\nhim',
#  'who',
#  'has',
#  'stopped',
#  'the',
#  'wheel',
#  'of',
#  'his\nwinepress?',
#  '',
#  'my',
#  'heart',
#  'become',
#  'a\ntree',
#  'heavy-laden',
#  'with',
#  'fruit',
#  'that',
#  'I',
#  'may\ngather',
#  'and',
#  'give',
#  'unto',
#  'them?\n\nAnd',
#  'shall',
#  'my',
#  'desires',
#  'flow',
#  'like',
#  'a\nfountain',
#  'that',
#  'I',
#  'may',
#  'fill',
#  'their',
#  'cups?\n\nAm',
#  'I',
#  'a',
#  'harp',
#  'that',
#  'the',
#  'hand',
#  'of',
#  'the',
#  'mighty\nmay',
#  'touch',
#  'me,',
#  'or',
#  'a',
#  'flute',
#  'that',
#  'his',
#  'breath\nmay',
#  'pass',
#  'through',
#  'me?\n\nA',
#  'seeker',
#  'of',
#  'silences',
#  'am',
#  'I,',
#  'and',
#  'what\ntreasure',
#  'have',
#  'I',
#  'found',
#  'in',
#  'silences',
#  'that',
#  'I\nmay',
#  'dispense',
#  'with',
#  'confidence?\n\nIf',
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  'what\nfields',
#  'have',
#  'I',
#  'sowed',
#  'the',
#  'seed,',
#  'and',
#  'in\nwhat',
#  'unremembered',
#  'seasons?\n\nIf',
#  'this',
#  'indeed',
#  'be',
#  'the',
#  'hour',
#  'in',
#  'which',
#  'I\nlift',
#  'up',
#  'my',
#  'lantern,',
#  'it',
#  'is',
#  'not',
#  'my',
#  'flame\nthat',
#  'shall',
#  'burn',
#  'therein.\n\nEmpty',
#  'and',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  'lantern,\n\nAnd',
#  'the',
#  'guardian',
#  'of',
#  'the',
#  'night',
#  'shall',
#  'fill\nit',
#  'with',
#  'oil',
#  'and',
#  'he',
#  'shall',
#  'light',
#  'it',
#  'also.\n\n*****\n\nThese',
#  'things',
#  'he',
#  'said',
#  'in',
#  'words.',
#  'But',
#  'much\nin',
#  'his',
#  'heart',
#  'remained',
#  'unsaid.',
#  'For',
#  '',
#  'could',
#  'not',
#  'speak',
#  'his',
#  'deeper\nsecret.\n\n*****\n\n[Illustration:',
#  '0020]\n\nAnd',
#  'when',
#  'he',
#  'entered',
#  'into',
#  'the',
#  'city',
#  'all\nthe',
#  'people',
#  'came',
#  'to',
#  'meet',
#  'him,',
#  'and',
#  'they\nwere',
#  'crying',
#  'out',
#  'to',
#  'him',
#  'as',
#  'with',
#  'one\nvoice.\n\nAnd',
#  'the',
#  'elders',
#  'of',
#  'the',
#  'city',
#  'stood',
#  'forth\nand',
#  'said:\n\nGo',
#  'not',
#  'yet',
#  'away',
#  'from',
#  'us.\n\nA',
#  'noontide',
#  'have',
#  'you',
#  'been',
#  'in',
#  'our\ntwilight,',
#  'and',
#  'your',
#  'youth',
#  'has',
#  'given',
#  'us\ndreams',
#  'to',
#  'dream.\n\nNo',
#  'stranger',
#  'are',
#  'you',
#  'among',
#  'us,',
#  'nor\na',
#  'guest,',
#  'but',
#  'our',
#  'son',
#  'and',
#  'our',
#  'dearly\nbeloved.\n\nSuffer',
#  'not',
#  'yet',
#  'our',
#  'eyes',
#  'to',
#  'hunger',
#  'for\nyour',
#  'face.\n\n*****\n\nAnd',
#  'the',
#  'priests',
#  'and',
#  'the',
#  'priestesses',
#  'said\nunto',
#  'him:\n\nLet',
#  'not',
#  'the',
#  'waves',
#  'of',
#  'the',
#  'sea',
#  'separate',
#  'us\nnow,',
#  'and',
#  'the',
#  'years',
#  'you',
#  'have',
#  'spent',
#  'in',
#  'our\nmidst',
#  'become',
#  'a',
#  'memory.\n\nYou',
#  'have',
#  'walked',
#  'among',
#  'us',
#  'a',
#  'spirit,\n',
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'a',
#  'light\nupon',
#  'our',
#  'faces.\n\nMuch',
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  'speechless\nwas',
#  'our',
#  'love,',
#  'and',
#  'with',
#  'veils',
#  'has',
#  'it',
#  'been\nveiled.\n\nYet',
#  'now',
#  'it',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  'and\nwould',
#  'stand',
#  'revealed',
#  'before',
#  'you.\n\nAnd',
#  'ever',
#  'has',
#  'it',
#  'been',
#  'that',
#  'love',
#  'knows\nnot',
#  'its',
#  'own',
#  'depth',
#  'until',
#  'the',
#  'hour',
#  'of\nseparation.\n\n*****\n\nAnd',
#  'others',
#  'came',
#  'also',
#  'and',
#  'entreated',
#  'him.\nBut',
#  'he',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  'bent\nhis',
#  'head;',
#  'and',
#  'those',
#  'who',
#  'stood',
#  'near',
#  'saw\nhis',
#  'tears',
#  'falling',
#  'upon',
#  'his',
#  'breast.\n\nAnd',
#  'he',
#  'and',
#  'the',
#  'people',
#  'proceeded',
#  'towards\nthe',
#  'great',
#  'square',
#  'before',
#  'the',
#  'temple.\n\nAnd',
#  'there',
#  'came',
#  'out',
#  'of',
#  'the',
#  'sanctuary',
#  'a\nwoman',
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  'she\nwas',
#  'a',
#  'seeress.\n\nAnd',
#  'he',
#  'looked',
#  'upon',
#  'her',
#  'with',
#  'exceeding\ntenderness,',
#  'for',
#  'it',
#  'was',
#  'she',
#  'who',
#  'had',
#  'first\nsought',
#  'and',
#  'believed',
#  'in',
#  'him',
#  'when',
#  'he',
#  'had\nbeen',
#  'but',
#  'a',
#  'day',
#  'in',
#  'their',
#  'city.',
#  '',
#  'hailed',
#  'him,',
#  'saying:\n\nProphet',
#  'of',
#  'God,',
#  'in',
#  'quest',
#  'of',
#  'the\nuttermost,',
#  'long',
#  'have',
#  'you',
#  'searched',
#  'the\ndistances',
#  'for',
#  'your',
#  'ship.\n\nAnd',
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'and',
#  'you',
#  'must\nneeds',
#  'go.\n\nDeep',
#  'is',
#  'your',
#  'longing',
#  'for',
#  'the',
#  'land',
#  'of\nyour',
#  'memories',
#  'and',
#  'the',
#  'dwelling',
#  'place\nof',
#  'your',
#  'greater',
#  'desires;',
#  'and',
#  'our',
#  'love\nwould',
#  'not',
#  'bind',
#  'you',
#  'nor',
#  'our',
#  'needs',
#  'hold\nyou.\n\nYet',
#  'this',
#  'we',
#  'ask',
#  'ere',
#  'you',
#  'leave',
#  'us,',
#  'that\nyou',
#  'speak',
#  'to',
#  'us',
#  'and',
#  'give',
#  'us',
#  'of',
#  'your\ntruth.\n\nAnd',
#  'we',
#  'will',
#  'give',
#  'it',
#  'unto',
#  'our',
#  'children,\nand',
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'and',
#  'it\nshall',
#  'not',
#  'perish.\n\nIn',
#  'your',
#  'aloneness',
#  'you',
#  'have',
#  'watched',
#  'with\nour',
#  'days,',
#  'and',
#  'in',
#  'your',
#  'wakefulness',
#  'you\nhave',
#  'listened',
#  'to',
#  'the',
#  'weeping',
#  'and',
#  'the\nlaughter',
#  'of',
#  'our',
#  'sleep.\n\nNow',
#  'therefore',
#  'disclose',
#  'us',
#  'to',
#  'ourselves,\nand',
#  'tell',
#  'us',
#  'all',
#  'that',
#  'has',
#  'been',
#  'shown\nyou',
#  'of',
#  'that',
#  'which',
#  'is',
#  'between',
#  'birth',
#  'and\ndeath.\n\n*****\n\nAnd',
#  'he',
#  'answered,\n\nPeople',
#  'of',
#  'Orphalese,',
#  'of',
#  ...]

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    '''
    Input: A string
    Output: A list of strings split on the line break (\n) character
        
    Example:
    Input: 'the\nbeloved'
    Output: ['the', 'beloved']
    '''
    
    # your code here
    if "\n" in x:
        x = [x.split(sep="\n")[0] , x.split(sep="\n")[1]]
        return x
    else:
        return x

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# your code here
prophet_line = list(map(line_break,prophet_reference))
prophet_line
# Out:
# ['the',
#  'chosen',
#  'and',
#  ['the', 'beloved,'],
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto',
#  'his',
#  ['own', 'day,'],
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'in',
#  'the',
#  ['city', 'of'],
#  'Orphalese',
#  'for',
#  'his',
#  'ship',
#  'that',
#  'was',
#  ['to', 'return'],
#  'and',
#  'bear',
#  'him',
#  'back',
#  'to',
#  'the',
#  'isle',
#  ['of', 'his'],
#  ['birth.', ''],
#  'in',
#  'the',
#  'twelfth',
#  'year,',
#  'on',
#  'the',
#  ['seventh', 'day'],
#  'of',
#  'Ielool,',
#  'the',
#  'month',
#  'of',
#  'reaping,',
#  ['he', 'climbed'],
#  'the',
#  'hill',
#  'without',
#  'the',
#  'city',
#  ['walls', 'and'],
#  'looked',
#  'seaward;',
#  'and',
#  'he',
#  'beheld',
#  ['his', 'ship'],
#  'coming',
#  'with',
#  'the',
#  ['mist.', ''],
#  'the',
#  'gates',
#  'of',
#  'his',
#  'heart',
#  'were',
#  ['flung', 'open,'],
#  'and',
#  'his',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'the',
#  ['sea.', 'And'],
#  'he',
#  'closed',
#  'his',
#  'eyes',
#  'and',
#  'prayed',
#  'in',
#  ['the', 'silences'],
#  'of',
#  'his',
#  ['soul.', ''],
#  'as',
#  'he',
#  'descended',
#  'the',
#  'hill,',
#  'a',
#  ['sadness', 'came'],
#  'upon',
#  'him,',
#  'and',
#  'he',
#  'thought',
#  'in',
#  ['his', 'heart:'],
#  'shall',
#  'I',
#  'go',
#  'in',
#  'peace',
#  'and',
#  ['without', 'sorrow?'],
#  'Nay,',
#  'not',
#  'without',
#  'a',
#  'wound',
#  'in',
#  ['the', 'spirit'],
#  'shall',
#  'I',
#  'leave',
#  'this',
#  'city.',
#  '',
#  'the',
#  'days',
#  'of',
#  'pain',
#  'I',
#  'have',
#  ['spent', 'within'],
#  'its',
#  'walls,',
#  'and',
#  'long',
#  'were',
#  ['the', 'nights'],
#  'of',
#  'aloneness;',
#  'and',
#  'who',
#  'can',
#  ['depart', 'from'],
#  'his',
#  'pain',
#  'and',
#  'his',
#  'aloneness',
#  ['without', 'regret?'],
#  'many',
#  'fragments',
#  'of',
#  'the',
#  'spirit',
#  'have',
#  ['I', 'scattered'],
#  'in',
#  'these',
#  'streets,',
#  'and',
#  'too',
#  ['many', 'are'],
#  'the',
#  'children',
#  'of',
#  'my',
#  'longing',
#  'that',
#  ['walk', 'naked'],
#  'among',
#  'these',
#  'hills,',
#  'and',
#  'I',
#  ['cannot', 'withdraw'],
#  'from',
#  'them',
#  'without',
#  'a',
#  'burden',
#  ['and', 'an'],
#  ['ache.', ''],
#  'is',
#  'not',
#  'a',
#  'garment',
#  'I',
#  'cast',
#  'off',
#  ['this', 'day,'],
#  'but',
#  'a',
#  'skin',
#  'that',
#  'I',
#  'tear',
#  'with',
#  'my',
#  ['own', 'hands.'],
#  'is',
#  'it',
#  'a',
#  'thought',
#  'I',
#  'leave',
#  'behind',
#  ['me,', 'but'],
#  'a',
#  'heart',
#  'made',
#  'sweet',
#  'with',
#  'hunger',
#  ['and', 'with'],
#  ['thirst.', ''],
#  'I',
#  'cannot',
#  'tarry',
#  ['longer.', ''],
#  'sea',
#  'that',
#  'calls',
#  'all',
#  'things',
#  'unto',
#  ['her', 'calls'],
#  'me,',
#  'and',
#  'I',
#  'must',
#  ['embark.', ''],
#  'to',
#  'stay,',
#  'though',
#  'the',
#  'hours',
#  'burn',
#  ['in', 'the'],
#  'night,',
#  'is',
#  'to',
#  'freeze',
#  'and',
#  ['crystallize', 'and'],
#  'be',
#  'bound',
#  'in',
#  'a',
#  ['mould.', ''],
#  'would',
#  'I',
#  'take',
#  'with',
#  'me',
#  'all',
#  'that',
#  ['is', 'here.'],
#  'But',
#  'how',
#  'shall',
#  ['I?', ''],
#  'voice',
#  'cannot',
#  'carry',
#  'the',
#  'tongue',
#  ['and', ''],
#  'lips',
#  'that',
#  'gave',
#  'it',
#  'wings.',
#  ['Alone', 'must'],
#  'it',
#  'seek',
#  'the',
#  ['ether.', ''],
#  'alone',
#  'and',
#  'without',
#  'his',
#  'nest',
#  'shall',
#  ['the', 'eagle'],
#  'fly',
#  'across',
#  'the',
#  ['sun.', ''],
#  'when',
#  'he',
#  'reached',
#  'the',
#  'foot',
#  'of',
#  ['the', 'hill,'],
#  'he',
#  'turned',
#  'again',
#  'towards',
#  'the',
#  ['sea,', 'and'],
#  'he',
#  'saw',
#  'his',
#  'ship',
#  'approaching',
#  ['the', 'harbour,'],
#  'and',
#  'upon',
#  'her',
#  'prow',
#  'the',
#  ['mariners,', 'the'],
#  'men',
#  'of',
#  'his',
#  'own',
#  ['land.', ''],
#  'his',
#  'soul',
#  'cried',
#  'out',
#  'to',
#  'them,',
#  'and',
#  ['he', 'said:'],
#  'of',
#  'my',
#  'ancient',
#  'mother,',
#  'you',
#  'riders',
#  ['of', 'the'],
#  ['tides,', ''],
#  'often',
#  'have',
#  'you',
#  'sailed',
#  'in',
#  'my',
#  ['dreams.', 'And'],
#  'now',
#  'you',
#  'come',
#  'in',
#  'my',
#  'awakening,',
#  ['which', 'is'],
#  'my',
#  'deeper',
#  ['dream.', ''],
#  'am',
#  'I',
#  'to',
#  'go,',
#  'and',
#  'my',
#  'eagerness',
#  ['with', 'sails'],
#  'full',
#  'set',
#  'awaits',
#  'the',
#  ['wind.', ''],
#  'another',
#  'breath',
#  'will',
#  'I',
#  'breathe',
#  ['in', 'this'],
#  'still',
#  'air,',
#  'only',
#  'another',
#  'loving',
#  ['look', 'cast'],
#  ['backward,', ''],
#  'then',
#  'I',
#  'shall',
#  'stand',
#  'among',
#  'you,',
#  ['a', 'seafarer'],
#  'among',
#  'seafarers.',
#  '',
#  ['you,', 'vast'],
#  'sea,',
#  'sleepless',
#  ['mother,', ''],
#  'alone',
#  'are',
#  'peace',
#  'and',
#  'freedom',
#  'to',
#  ['the', 'river'],
#  'and',
#  'the',
#  ['stream,', ''],
#  'another',
#  'winding',
#  'will',
#  'this',
#  ['stream', 'make,'],
#  'only',
#  'another',
#  'murmur',
#  'in',
#  'this',
#  ['glade,', ''],
#  'then',
#  'shall',
#  'I',
#  'come',
#  'to',
#  'you,',
#  ['a', 'boundless'],
#  'drop',
#  'to',
#  'a',
#  'boundless',
#  ['ocean.', ''],
#  'as',
#  'he',
#  'walked',
#  'he',
#  'saw',
#  'from',
#  'afar',
#  ['men', 'and'],
#  'women',
#  'leaving',
#  'their',
#  'fields',
#  'and',
#  ['their', 'vineyards'],
#  'and',
#  'hastening',
#  'towards',
#  'the',
#  ['city', 'gates.'],
#  'he',
#  'heard',
#  'their',
#  'voices',
#  'calling',
#  ['his', 'name,'],
#  'and',
#  'shouting',
#  'from',
#  'field',
#  'to',
#  ['field', 'telling'],
#  'one',
#  'another',
#  'of',
#  'the',
#  'coming',
#  'of',
#  ['his', 'ship.'],
#  'he',
#  'said',
#  'to',
#  ['himself:', ''],
#  'the',
#  'day',
#  'of',
#  'parting',
#  'be',
#  'the',
#  'day',
#  ['of', 'gathering?'],
#  'shall',
#  'it',
#  'be',
#  'said',
#  'that',
#  'my',
#  'eve',
#  'was',
#  ['in', 'truth'],
#  'my',
#  ['dawn?', ''],
#  'what',
#  'shall',
#  'I',
#  'give',
#  'unto',
#  'him',
#  'who',
#  ['has', 'left'],
#  'his',
#  'plough',
#  'in',
#  'midfurrow,',
#  'or',
#  ['to', 'him'],
#  'who',
#  'has',
#  'stopped',
#  'the',
#  'wheel',
#  'of',
#  ['his', 'winepress?'],
#  '',
#  'my',
#  'heart',
#  'become',
#  ['a', 'tree'],
#  'heavy-laden',
#  'with',
#  'fruit',
#  'that',
#  'I',
#  ['may', 'gather'],
#  'and',
#  'give',
#  'unto',
#  ['them?', ''],
#  'shall',
#  'my',
#  'desires',
#  'flow',
#  'like',
#  ['a', 'fountain'],
#  'that',
#  'I',
#  'may',
#  'fill',
#  'their',
#  ['cups?', ''],
#  'I',
#  'a',
#  'harp',
#  'that',
#  'the',
#  'hand',
#  'of',
#  'the',
#  ['mighty', 'may'],
#  'touch',
#  'me,',
#  'or',
#  'a',
#  'flute',
#  'that',
#  'his',
#  ['breath', 'may'],
#  'pass',
#  'through',
#  ['me?', ''],
#  'seeker',
#  'of',
#  'silences',
#  'am',
#  'I,',
#  'and',
#  ['what', 'treasure'],
#  'have',
#  'I',
#  'found',
#  'in',
#  'silences',
#  'that',
#  ['I', 'may'],
#  'dispense',
#  'with',
#  ['confidence?', ''],
#  'this',
#  'is',
#  'my',
#  'day',
#  'of',
#  'harvest,',
#  'in',
#  ['what', 'fields'],
#  'have',
#  'I',
#  'sowed',
#  'the',
#  'seed,',
#  'and',
#  ['in', 'what'],
#  'unremembered',
#  ['seasons?', ''],
#  'this',
#  'indeed',
#  'be',
#  'the',
#  'hour',
#  'in',
#  'which',
#  ['I', 'lift'],
#  'up',
#  'my',
#  'lantern,',
#  'it',
#  'is',
#  'not',
#  'my',
#  ['flame', 'that'],
#  'shall',
#  'burn',
#  ['therein.', ''],
#  'and',
#  'dark',
#  'shall',
#  'I',
#  'raise',
#  'my',
#  ['lantern,', ''],
#  'the',
#  'guardian',
#  'of',
#  'the',
#  'night',
#  'shall',
#  ['fill', 'it'],
#  'with',
#  'oil',
#  'and',
#  'he',
#  'shall',
#  'light',
#  'it',
#  ['also.', ''],
#  'things',
#  'he',
#  'said',
#  'in',
#  'words.',
#  'But',
#  ['much', 'in'],
#  'his',
#  'heart',
#  'remained',
#  'unsaid.',
#  'For',
#  '',
#  'could',
#  'not',
#  'speak',
#  'his',
#  ['deeper', 'secret.'],
#  ['0020]', ''],
#  'when',
#  'he',
#  'entered',
#  'into',
#  'the',
#  'city',
#  ['all', 'the'],
#  'people',
#  'came',
#  'to',
#  'meet',
#  'him,',
#  'and',
#  ['they', 'were'],
#  'crying',
#  'out',
#  'to',
#  'him',
#  'as',
#  'with',
#  ['one', 'voice.'],
#  'the',
#  'elders',
#  'of',
#  'the',
#  'city',
#  'stood',
#  ['forth', 'and'],
#  ['said:', ''],
#  'not',
#  'yet',
#  'away',
#  'from',
#  ['us.', ''],
#  'noontide',
#  'have',
#  'you',
#  'been',
#  'in',
#  ['our', 'twilight,'],
#  'and',
#  'your',
#  'youth',
#  'has',
#  'given',
#  ['us', 'dreams'],
#  'to',
#  ['dream.', ''],
#  'stranger',
#  'are',
#  'you',
#  'among',
#  'us,',
#  ['nor', 'a'],
#  'guest,',
#  'but',
#  'our',
#  'son',
#  'and',
#  'our',
#  ['dearly', 'beloved.'],
#  'not',
#  'yet',
#  'our',
#  'eyes',
#  'to',
#  'hunger',
#  ['for', 'your'],
#  ['face.', ''],
#  'the',
#  'priests',
#  'and',
#  'the',
#  'priestesses',
#  ['said', 'unto'],
#  ['him:', ''],
#  'not',
#  'the',
#  'waves',
#  'of',
#  'the',
#  'sea',
#  'separate',
#  ['us', 'now,'],
#  'and',
#  'the',
#  'years',
#  'you',
#  'have',
#  'spent',
#  'in',
#  ['our', 'midst'],
#  'become',
#  'a',
#  ['memory.', ''],
#  'have',
#  'walked',
#  'among',
#  'us',
#  'a',
#  ['spirit,', ''],
#  'your',
#  'shadow',
#  'has',
#  'been',
#  'a',
#  ['light', 'upon'],
#  'our',
#  ['faces.', ''],
#  'have',
#  'we',
#  'loved',
#  'you.',
#  'But',
#  ['speechless', 'was'],
#  'our',
#  'love,',
#  'and',
#  'with',
#  'veils',
#  'has',
#  'it',
#  ['been', 'veiled.'],
#  'now',
#  'it',
#  'cries',
#  'aloud',
#  'unto',
#  'you,',
#  ['and', 'would'],
#  'stand',
#  'revealed',
#  'before',
#  ['you.', ''],
#  'ever',
#  'has',
#  'it',
#  'been',
#  'that',
#  'love',
#  ['knows', 'not'],
#  'its',
#  'own',
#  'depth',
#  'until',
#  'the',
#  'hour',
#  ['of', 'separation.'],
#  'others',
#  'came',
#  'also',
#  'and',
#  'entreated',
#  ['him.', 'But'],
#  'he',
#  'answered',
#  'them',
#  'not.',
#  'He',
#  'only',
#  ['bent', 'his'],
#  'head;',
#  'and',
#  'those',
#  'who',
#  'stood',
#  'near',
#  ['saw', 'his'],
#  'tears',
#  'falling',
#  'upon',
#  'his',
#  ['breast.', ''],
#  'he',
#  'and',
#  'the',
#  'people',
#  'proceeded',
#  ['towards', 'the'],
#  'great',
#  'square',
#  'before',
#  'the',
#  ['temple.', ''],
#  'there',
#  'came',
#  'out',
#  'of',
#  'the',
#  'sanctuary',
#  ['a', 'woman'],
#  'whose',
#  'name',
#  'was',
#  'Almitra.',
#  'And',
#  ['she', 'was'],
#  'a',
#  ['seeress.', ''],
#  'he',
#  'looked',
#  'upon',
#  'her',
#  'with',
#  ['exceeding', 'tenderness,'],
#  'for',
#  'it',
#  'was',
#  'she',
#  'who',
#  'had',
#  ['first', 'sought'],
#  'and',
#  'believed',
#  'in',
#  'him',
#  'when',
#  'he',
#  ['had', 'been'],
#  'but',
#  'a',
#  'day',
#  'in',
#  'their',
#  'city.',
#  '',
#  'hailed',
#  'him,',
#  ['saying:', ''],
#  'of',
#  'God,',
#  'in',
#  'quest',
#  'of',
#  ['the', 'uttermost,'],
#  'long',
#  'have',
#  'you',
#  'searched',
#  ['the', 'distances'],
#  'for',
#  'your',
#  ['ship.', ''],
#  'now',
#  'your',
#  'ship',
#  'has',
#  'come,',
#  'and',
#  'you',
#  ['must', 'needs'],
#  ['go.', ''],
#  'is',
#  'your',
#  'longing',
#  'for',
#  'the',
#  'land',
#  ['of', 'your'],
#  'memories',
#  'and',
#  'the',
#  'dwelling',
#  ['place', 'of'],
#  'your',
#  'greater',
#  'desires;',
#  'and',
#  'our',
#  ['love', 'would'],
#  'not',
#  'bind',
#  'you',
#  'nor',
#  'our',
#  'needs',
#  ['hold', 'you.'],
#  'this',
#  'we',
#  'ask',
#  'ere',
#  'you',
#  'leave',
#  'us,',
#  ['that', 'you'],
#  'speak',
#  'to',
#  'us',
#  'and',
#  'give',
#  'us',
#  'of',
#  ['your', 'truth.'],
#  'we',
#  'will',
#  'give',
#  'it',
#  'unto',
#  'our',
#  ['children,', 'and'],
#  'they',
#  'unto',
#  'their',
#  'children,',
#  'and',
#  ['it', 'shall'],
#  'not',
#  ['perish.', ''],
#  'your',
#  'aloneness',
#  'you',
#  'have',
#  'watched',
#  ['with', 'our'],
#  'days,',
#  'and',
#  'in',
#  'your',
#  'wakefulness',
#  ['you', 'have'],
#  'listened',
#  'to',
#  'the',
#  'weeping',
#  'and',
#  ['the', 'laughter'],
#  'of',
#  'our',
#  ['sleep.', ''],
#  'therefore',
#  'disclose',
#  'us',
#  'to',
#  ['ourselves,', 'and'],
#  'tell',
#  'us',
#  'all',
#  'that',
#  'has',
#  'been',
#  ['shown', 'you'],
#  'of',
#  'that',
#  'which',
#  'is',
#  'between',
#  'birth',
#  ['and', 'death.'],
#  'he',
#  ['answered,', ''],
#  'of',
#  'Orphalese,',
#  'of',
#  ...]

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
prophet_flat = [i for sub in prophet_line for i in sub if len(i)>1]
prophet_flat
# Out:
# ['the',
#  'beloved,',
#  'own',
#  'day,',
#  'city',
#  'of',
#  'to',
#  'return',
#  'of',
#  'his',
#  'birth.',
#  'seventh',
#  'day',
#  'he',
#  'climbed',
#  'walls',
#  'and',
#  'his',
#  'ship',
#  'mist.',
#  'flung',
#  'open,',
#  'sea.',
#  'And',
#  'the',
#  'silences',
#  'soul.',
#  'sadness',
#  'came',
#  'his',
#  'heart:',
#  'without',
#  'sorrow?',
#  'the',
#  'spirit',
#  'spent',
#  'within',
#  'the',
#  'nights',
#  'depart',
#  'from',
#  'without',
#  'regret?',
#  'scattered',
#  'many',
#  'are',
#  'walk',
#  'naked',
#  'cannot',
#  'withdraw',
#  'and',
#  'an',
#  'ache.',
#  'this',
#  'day,',
#  'own',
#  'hands.',
#  'me,',
#  'but',
#  'and',
#  'with',
#  'thirst.',
#  'longer.',
#  'her',
#  'calls',
#  'embark.',
#  'in',
#  'the',
#  'crystallize',
#  'and',
#  'mould.',
#  'is',
#  'here.',
#  'I?',
#  'and',
#  'Alone',
#  'must',
#  'ether.',
#  'the',
#  'eagle',
#  'sun.',
#  'the',
#  'hill,',
#  'sea,',
#  'and',
#  'the',
#  'harbour,',
#  'mariners,',
#  'the',
#  'land.',
#  'he',
#  'said:',
#  'of',
#  'the',
#  'tides,',
#  'dreams.',
#  'And',
#  'which',
#  'is',
#  'dream.',
#  'with',
#  'sails',
#  'wind.',
#  'in',
#  'this',
#  'look',
#  'cast',
#  'backward,',
#  'seafarer',
#  'you,',
#  'vast',
#  'mother,',
#  'the',
#  'river',
#  'stream,',
#  'stream',
#  'make,',
#  'glade,',
#  'boundless',
#  'ocean.',
#  'men',
#  'and',
#  'their',
#  'vineyards',
#  'city',
#  'gates.',
#  'his',
#  'name,',
#  'field',
#  'telling',
#  'his',
#  'ship.',
#  'himself:',
#  'of',
#  'gathering?',
#  'in',
#  'truth',
#  'dawn?',
#  'has',
#  'left',
#  'to',
#  'him',
#  'his',
#  'winepress?',
#  'tree',
#  'may',
#  'gather',
#  'them?',
#  'fountain',
#  'cups?',
#  'mighty',
#  'may',
#  'breath',
#  'may',
#  'me?',
#  'what',
#  'treasure',
#  'may',
#  'confidence?',
#  'what',
#  'fields',
#  'in',
#  'what',
#  'seasons?',
#  'lift',
#  'flame',
#  'that',
#  'therein.',
#  'lantern,',
#  'fill',
#  'it',
#  'also.',
#  'much',
#  'in',
#  'deeper',
#  'secret.',
#  '0020]',
#  'all',
#  'the',
#  'they',
#  'were',
#  'one',
#  'voice.',
#  'forth',
#  'and',
#  'said:',
#  'us.',
#  'our',
#  'twilight,',
#  'us',
#  'dreams',
#  'dream.',
#  'nor',
#  'dearly',
#  'beloved.',
#  'for',
#  'your',
#  'face.',
#  'said',
#  'unto',
#  'him:',
#  'us',
#  'now,',
#  'our',
#  'midst',
#  'memory.',
#  'spirit,',
#  'light',
#  'upon',
#  'faces.',
#  'speechless',
#  'was',
#  'been',
#  'veiled.',
#  'and',
#  'would',
#  'you.',
#  'knows',
#  'not',
#  'of',
#  'separation.',
#  'him.',
#  'But',
#  'bent',
#  'his',
#  'saw',
#  'his',
#  'breast.',
#  'towards',
#  'the',
#  'temple.',
#  'woman',
#  'she',
#  'was',
#  'seeress.',
#  'exceeding',
#  'tenderness,',
#  'first',
#  'sought',
#  'had',
#  'been',
#  'saying:',
#  'the',
#  'uttermost,',
#  'the',
#  'distances',
#  'ship.',
#  'must',
#  'needs',
#  'go.',
#  'of',
#  'your',
#  'place',
#  'of',
#  'love',
#  'would',
#  'hold',
#  'you.',
#  'that',
#  'you',
#  'your',
#  'truth.',
#  'children,',
#  'and',
#  'it',
#  'shall',
#  'perish.',
#  'with',
#  'our',
#  'you',
#  'have',
#  'the',
#  'laughter',
#  'sleep.',
#  'ourselves,',
#  'and',
#  'shown',
#  'you',
#  'and',
#  'death.',
#  'answered,',
#  'now',
#  'moving',
#  'souls?',
#  '*****',
#  'of',
#  '_Love_.',
#  'upon',
#  'the',
#  'stillness',
#  'upon',
#  'he',
#  'said:',
#  'him,',
#  'steep.',
#  'to',
#  'him,',
#  'his',
#  'pinions',
#  'you.',
#  'in',
#  'him,',
#  'dreams',
#  'as',
#  'garden.',
#  'shall',
#  'he',
#  'your',
#  'growth',
#  'pruning.',
#  'and',
#  'branches',
#  'that',
#  'sun,',
#  'and',
#  'shake',
#  'the',
#  'earth.',
#  'unto',
#  'himself.',
#  'naked.',
#  'your',
#  'husks.',
#  'whiteness.',
#  'pliant;',
#  'sacred',
#  'fire,',
#  'bread',
#  'for',
#  'feast.',
#  'you',
#  'that',
#  'your',
#  'heart,',
#  'fragment',
#  'heart.',
#  'only',
#  'love’s',
#  'pleasure,',
#  'you',
#  'cover',
#  'of',
#  'love’s',
#  'threshing-floor,',
#  'you',
#  'shall',
#  'your',
#  'laughter,',
#  'your',
#  'tears.',
#  'takes',
#  'naught',
#  'itself.',
#  'be',
#  'possessed;',
#  'love.',
#  '“God',
#  'is',
#  'in',
#  'the',
#  'God.”',
#  'course',
#  'of',
#  'you',
#  'worthy,',
#  'course.',
#  'fulfil',
#  'itself.',
#  'have',
#  'desires,',
#  'desires:',
#  'that',
#  'sings',
#  'tenderness.',
#  'understanding',
#  'of',
#  'love;',
#  'joyfully.',
#  'and',
#  'give',
#  'loving;',
#  'meditate',
#  'love’s',
#  'ecstacy;',
#  'with',
#  'gratitude;',
#  'for',
#  'the',
#  'of',
#  'praise',
#  'lips.',
#  '0029]',
#  '*****',
#  'said,',
#  'And',
#  'master?',
#  'saying:',
#  'you',
#  'shall',
#  'forevermore.',
#  'white',
#  'wings',
#  'days.',
#  'the',
#  'silent',
#  'God.',
#  'your',
#  'togetherness,',
#  'dance',
#  'between',
#  'you.',
#  'of',
#  'love:',
#  'between',
#  'the',
#  'souls.',
#  'from',
#  'one',
#  'cup.',
#  'eat',
#  'not',
#  'and',
#  'dance',
#  'let',
#  'each',
#  'alone,',
#  'alone',
#  'though',
#  'music.',
#  'each',
#  'other’s',
#  'keeping.',
#  'contain',
#  'your',
#  'hearts.',
#  'near',
#  'together:',
#  'stand',
#  'apart,',
#  'grow',
#  'not',
#  'shadow.',
#  '0032]',
#  '*****',
#  'babe',
#  'against',
#  'of',
#  '_Children_.',
#  'said:',
#  'children.',
#  'of',
#  'Life’s',
#  'itself.',
#  'you,',
#  'they',
#  'belong',
#  'you.',
#  'your',
#  'thoughts,',
#  'thoughts.',
#  'their',
#  'souls,',
#  'of',
#  'tomorrow,',
#  'not',
#  'even',
#  'dreams.',
#  'seek',
#  'not',
#  'with',
#  'yesterday.',
#  'your',
#  'children',
#  'sent',
#  'forth.',
#  'path',
#  'of',
#  'with',
#  'His',
#  'swift',
#  'and',
#  'far.',
#  'be',
#  'for',
#  'gladness;',
#  'that',
#  'flies,',
#  'is',
#  'stable.',
#  '*****',
#  'of',
#  '_Giving_.',
#  'answered:',
#  'of',
#  'your',
#  'possessions.',
#  'you',
#  'truly',
#  'give.',
#  'things',
#  'you',
#  'need',
#  'them',
#  'tomorrow?',
#  'bring',
#  'to',
#  'bones',
#  'in',
#  'the',
#  'pilgrims',
#  'city?',
#  'need',
#  'itself?',
#  'is',
#  'full,',
#  'unquenchable?',
#  'the',
#  'give',
#  'it',
#  'hidden',
#  'desire',
#  'unwholesome.',
#  'and',
#  'give',
#  'all.',
#  'and',
#  'the',
#  'is',
#  'never',
#  'empty.',
#  'and',
#  'that',
#  'reward.',
#  'pain,',
#  'and',
#  'baptism.',
#  'know',
#  'not',
#  'seek',
#  'joy,',
#  'of',
#  'virtue;',
#  'myrtle',
#  'breathes',
#  'space.',
#  'God',
#  'speaks,',
#  'He',
#  'smiles',
#  'earth.',
#  '0039]',
#  'it',
#  'is',
#  'through',
#  'understanding;',
#  'for',
#  'greater',
#  'than',
#  'giving.',
#  'withhold?',
#  'given;',
#  'season',
#  'of',
#  'your',
#  'inheritors’.',
#  'only',
#  'to',
#  'deserving.”',
#  'so,',
#  'nor',
#  'pasture.',
#  'to',
#  'withhold',
#  'perish.',
#  'his',
#  'days',
#  'all',
#  'else',
#  'you.',
#  'from',
#  'the',
#  'his',
#  'cup',
#  'stream.',
#  'be,',
#  'than',
#  'courage',
#  'and',
#  'of',
#  'receiving?',
#  'rend',
#  'pride,',
#  'that',
#  'and',
#  'their',
#  'unabashed?',
#  'to',
#  'be',
#  'giving.',
#  'unto',
#  'life--while',
#  'giver,',
#  'witness.',
#  'are',
#  'all',
#  'of',
#  'gratitude,',
#  'upon',
#  'yourself',
#  'gives.',
#  'on',
#  'his',
#  'wings;',
#  'is',
#  'ito',
#  'the',
#  'freehearted',
#  'God',
#  'for',
#  'father.',
#  '0042]',
#  '*****',
#  'an',
#  'inn,',
#  'and',
#  'Drinking_.',
#  'said:',
#  'the',
#  'fragrance',
#  'air',
#  'plant',
#  'light.',
#  'rob',
#  'the',
#  'to',
#  'quench',
#  'an',
#  'act',
#  'worship,',
#  'on',
#  'which',
#  'of',
#  'forest',
#  'that',
#  'which',
#  'innocent',
#  'in',
#  'man.',
#  'your',
#  'heart,',
#  'too',
#  'am',
#  'consumed.',
#  'into',
#  'my',
#  'mightier',
#  'hand.',
#  'but',
#  'the',
#  'heaven.”',
#  'your',
#  'teeth,',
#  'heart,',
#  'body,',
#  'shall',
#  'blossom',
#  'heart,',
#  'breath,',
#  'And',
#  'through',
#  'all',
#  'seasons.”',
#  'gather',
#  'the',
#  'the',
#  'winepress,',
#  'heart,',
#  'shall',
#  'be',
#  'winepress,',
#  'in',
#  'eternal',
#  'vessels.”',
#  'wine,',
#  'song',
#  'for',
#  'cup;',
#  'remembrance',
#  'for',
#  'the',
#  'winepress.',
#  'Speak',
#  'to',
#  '_Work_.',
#  'saying:',
#  'the',
#  'earth',
#  'earth.',
#  'stranger',
#  'unto',
#  'of',
#  'life’s',
#  'in',
#  'majesty',
#  'the',
#  'infinite.',
#  'through',
#  'whose',
#  'hours',
#  'turns',
#  'music.',
#  'and',
#  'silent,',
#  'in',
#  'unison?',
#  'curse',
#  'misfortune.',
#  'you',
#  'fulfil',
#  'dream,',
#  'was',
#  'born,',
#  'you',
#  'are',
#  'life,',
#  'be',
#  'intimate',
#  'secret.',
#  'an',
#  'affliction',
#  'flesh',
#  'answer',
#  'of',
#  'your',
#  'is',
#  'written.',
#  'is',
#  'darkness,',
#  'echo',
#  'what',
#  'weary.',
#  'darkness',
#  '‘save',
#  'urge,',
#  'is',
#  'knowledge,',
#  'when',
#  'there',
#  'work,',
#  'is',
#  'love;',
#  'bind',
#  'one',
#  'another,',
#  'God.',
#  'love?',
#  'threads',
#  'drawn',
#  'your',
#  'beloved',
#  'cloth.',
#  'affection,',
#  'even',
#  'in',
#  'that',
#  'house.',
#  'and',
#  'reap',
#  'if',
#  'your',
#  'fruit.',
#  'fashion',
#  'with',
#  'spirit,',
#  'dead',
#  'are',
#  'watching.',
#  'if',
#  'speaking',
#  'in',
#  'marble,',
#  'own',
#  'soul',
#  'who',
#  'ploughs',
#  'seizes',
#  'the',
#  'the',
#  'likeness',
#  'who',
#  'makes',
#  'feet.”',
#  'the',
#  'overwakefulness',
#  'the',
#  'wind',
#  'the',
#  'giant',
#  'the',
#  'blades',
#  'grass;',
#  'the',
#  'voice',
#  'made',
#  'sweeter',
#  'loving.',
#  'visible.',
#  'but',
#  'only',
#  'that',
#  'you',
#  'at',
#  'the',
#  'of',
#  'those',
#  'joy.',
#  'indifference,',
#  'you',
#  'but',
#  'half',
#  'hunger.',
#  'the',
#  'grapes,',
#  'in',
#  'the',
#  'as',
#  'angels,',
#  'you',
#  'muffle',
#  'the',
#  'day',
#  'night.',
#  '*****',
#  'of',
#  '_Joy',
#  'Sorrow_.',
#  'answered:',
#  'unmasked.',
#  'your',
#  'laughter',
#  'filled',
#  'with',
#  'tears.',
#  'be?',
#  'your',
#  'being,',
#  'contain.',
#  'the',
#  'very',
#  'potter’s',
#  'oven?',
#  'your',
#  'spirit,',
#  'hollowed',
#  'with',
#  'knives?',
#  'your',
#  'heart',
#  'only',
#  'that',
#  'is',
#  'giving',
#  'joy.',
#  'in',
#  'that',
#  'in',
#  'which',
#  'has',
#  'delight.',
#  'than',
#  'sorrow,”',
#  'is',
#  'the',
#  'greater.”',
#  'are',
#  'inseparable.',
#  'sits',
#  'alone',
#  'remember',
#  'that',
#  'bed.',
#  'scales',
#  'between',
#  'joy.',
#  'at',
#  'standstill',
#  'balanced.',
#  'to',
#  'weigh',
#  'needs',
#  'must',
#  'or',
#  'fall.',
#  '*****',
#  'said,',
#  'Speak',
#  '_Houses_.',
#  'said:',
#  'the',
#  'wilderness',
#  'within',
#  'the',
#  'walls.',
#  'in',
#  'your',
#  'in',
#  'you,',
#  'alone.',
#  'body.',
#  'the',
#  'stillness',
#  'not',
#  'dreamless.',
#  'dream?',
#  'and',
#  'grove',
#  'or',
#  'hilltop?',
#  'houses',
#  'into',
#  'scatter',
#  'them',
#  'meadow.',
#  'and',
#  'the',
#  'you',
#  'through',
#  'vineyards,',
#  'fragrance',
#  'of',
#  'garments.',
#  'be.',
#  'gathered',
#  'you',
#  'fear',
#  'shall',
#  'little',
#  'longer',
#  'separate',
#  'your',
#  'fields.',
#  'what',
#  'have',
#  'it',
#  'you',
#  'doors?',
#  'that',
#  'reveals',
#  'power?',
#  'glimmering',
#  'arches',
#  'the',
#  'mind?',
#  'heart',
#  'from',
#  'stone',
#  'to',
#  'mountain?',
#  'houses?',
#  'lust',
#  'for',
#  'that',
#  'then',
#  'becomes',
#  'master?',
#  'with',
#  'hook',
#  'your',
#  'larger',
#  'desires.',
#  'heart',
#  'is',
#  'iron.',
#  'by',
#  'your',
#  'the',
#  'flesh.',
#  'and',
#  'lays',
#  'fragile',
#  'vessels.',
#  'murders',
#  'the',
#  'walks',
#  'grinning',
#  'funeral.',
#  'restless',
#  'in',
#  'nor',
#  'tamed.',
#  'mast.',
#  'that',
#  'that',
#  'guards',
#  'eye.',
#  'you',
#  'may',
#  'your',
#  'heads',
#  'ceiling,',
#  ...]

# %%
# your code here

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    
    word_list = ['and', 'the', 'a', 'an']


    # your code here
    
    if x in word_list:
        return False
    else:
        return True

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
# your code here
prophet_filter = list(filter(word_filter,prophet_flat))
prophet_filter
# Out:
# ['beloved,',
#  'own',
#  'day,',
#  'city',
#  'of',
#  'to',
#  'return',
#  'of',
#  'his',
#  'birth.',
#  'seventh',
#  'day',
#  'he',
#  'climbed',
#  'walls',
#  'his',
#  'ship',
#  'mist.',
#  'flung',
#  'open,',
#  'sea.',
#  'And',
#  'silences',
#  'soul.',
#  'sadness',
#  'came',
#  'his',
#  'heart:',
#  'without',
#  'sorrow?',
#  'spirit',
#  'spent',
#  'within',
#  'nights',
#  'depart',
#  'from',
#  'without',
#  'regret?',
#  'scattered',
#  'many',
#  'are',
#  'walk',
#  'naked',
#  'cannot',
#  'withdraw',
#  'ache.',
#  'this',
#  'day,',
#  'own',
#  'hands.',
#  'me,',
#  'but',
#  'with',
#  'thirst.',
#  'longer.',
#  'her',
#  'calls',
#  'embark.',
#  'in',
#  'crystallize',
#  'mould.',
#  'is',
#  'here.',
#  'I?',
#  'Alone',
#  'must',
#  'ether.',
#  'eagle',
#  'sun.',
#  'hill,',
#  'sea,',
#  'harbour,',
#  'mariners,',
#  'land.',
#  'he',
#  'said:',
#  'of',
#  'tides,',
#  'dreams.',
#  'And',
#  'which',
#  'is',
#  'dream.',
#  'with',
#  'sails',
#  'wind.',
#  'in',
#  'this',
#  'look',
#  'cast',
#  'backward,',
#  'seafarer',
#  'you,',
#  'vast',
#  'mother,',
#  'river',
#  'stream,',
#  'stream',
#  'make,',
#  'glade,',
#  'boundless',
#  'ocean.',
#  'men',
#  'their',
#  'vineyards',
#  'city',
#  'gates.',
#  'his',
#  'name,',
#  'field',
#  'telling',
#  'his',
#  'ship.',
#  'himself:',
#  'of',
#  'gathering?',
#  'in',
#  'truth',
#  'dawn?',
#  'has',
#  'left',
#  'to',
#  'him',
#  'his',
#  'winepress?',
#  'tree',
#  'may',
#  'gather',
#  'them?',
#  'fountain',
#  'cups?',
#  'mighty',
#  'may',
#  'breath',
#  'may',
#  'me?',
#  'what',
#  'treasure',
#  'may',
#  'confidence?',
#  'what',
#  'fields',
#  'in',
#  'what',
#  'seasons?',
#  'lift',
#  'flame',
#  'that',
#  'therein.',
#  'lantern,',
#  'fill',
#  'it',
#  'also.',
#  'much',
#  'in',
#  'deeper',
#  'secret.',
#  '0020]',
#  'all',
#  'they',
#  'were',
#  'one',
#  'voice.',
#  'forth',
#  'said:',
#  'us.',
#  'our',
#  'twilight,',
#  'us',
#  'dreams',
#  'dream.',
#  'nor',
#  'dearly',
#  'beloved.',
#  'for',
#  'your',
#  'face.',
#  'said',
#  'unto',
#  'him:',
#  'us',
#  'now,',
#  'our',
#  'midst',
#  'memory.',
#  'spirit,',
#  'light',
#  'upon',
#  'faces.',
#  'speechless',
#  'was',
#  'been',
#  'veiled.',
#  'would',
#  'you.',
#  'knows',
#  'not',
#  'of',
#  'separation.',
#  'him.',
#  'But',
#  'bent',
#  'his',
#  'saw',
#  'his',
#  'breast.',
#  'towards',
#  'temple.',
#  'woman',
#  'she',
#  'was',
#  'seeress.',
#  'exceeding',
#  'tenderness,',
#  'first',
#  'sought',
#  'had',
#  'been',
#  'saying:',
#  'uttermost,',
#  'distances',
#  'ship.',
#  'must',
#  'needs',
#  'go.',
#  'of',
#  'your',
#  'place',
#  'of',
#  'love',
#  'would',
#  'hold',
#  'you.',
#  'that',
#  'you',
#  'your',
#  'truth.',
#  'children,',
#  'it',
#  'shall',
#  'perish.',
#  'with',
#  'our',
#  'you',
#  'have',
#  'laughter',
#  'sleep.',
#  'ourselves,',
#  'shown',
#  'you',
#  'death.',
#  'answered,',
#  'now',
#  'moving',
#  'souls?',
#  '*****',
#  'of',
#  '_Love_.',
#  'upon',
#  'stillness',
#  'upon',
#  'he',
#  'said:',
#  'him,',
#  'steep.',
#  'to',
#  'him,',
#  'his',
#  'pinions',
#  'you.',
#  'in',
#  'him,',
#  'dreams',
#  'as',
#  'garden.',
#  'shall',
#  'he',
#  'your',
#  'growth',
#  'pruning.',
#  'branches',
#  'that',
#  'sun,',
#  'shake',
#  'earth.',
#  'unto',
#  'himself.',
#  'naked.',
#  'your',
#  'husks.',
#  'whiteness.',
#  'pliant;',
#  'sacred',
#  'fire,',
#  'bread',
#  'for',
#  'feast.',
#  'you',
#  'that',
#  'your',
#  'heart,',
#  'fragment',
#  'heart.',
#  'only',
#  'love’s',
#  'pleasure,',
#  'you',
#  'cover',
#  'of',
#  'love’s',
#  'threshing-floor,',
#  'you',
#  'shall',
#  'your',
#  'laughter,',
#  'your',
#  'tears.',
#  'takes',
#  'naught',
#  'itself.',
#  'be',
#  'possessed;',
#  'love.',
#  '“God',
#  'is',
#  'in',
#  'God.”',
#  'course',
#  'of',
#  'you',
#  'worthy,',
#  'course.',
#  'fulfil',
#  'itself.',
#  'have',
#  'desires,',
#  'desires:',
#  'that',
#  'sings',
#  'tenderness.',
#  'understanding',
#  'of',
#  'love;',
#  'joyfully.',
#  'give',
#  'loving;',
#  'meditate',
#  'love’s',
#  'ecstacy;',
#  'with',
#  'gratitude;',
#  'for',
#  'of',
#  'praise',
#  'lips.',
#  '0029]',
#  '*****',
#  'said,',
#  'And',
#  'master?',
#  'saying:',
#  'you',
#  'shall',
#  'forevermore.',
#  'white',
#  'wings',
#  'days.',
#  'silent',
#  'God.',
#  'your',
#  'togetherness,',
#  'dance',
#  'between',
#  'you.',
#  'of',
#  'love:',
#  'between',
#  'souls.',
#  'from',
#  'one',
#  'cup.',
#  'eat',
#  'not',
#  'dance',
#  'let',
#  'each',
#  'alone,',
#  'alone',
#  'though',
#  'music.',
#  'each',
#  'other’s',
#  'keeping.',
#  'contain',
#  'your',
#  'hearts.',
#  'near',
#  'together:',
#  'stand',
#  'apart,',
#  'grow',
#  'not',
#  'shadow.',
#  '0032]',
#  '*****',
#  'babe',
#  'against',
#  'of',
#  '_Children_.',
#  'said:',
#  'children.',
#  'of',
#  'Life’s',
#  'itself.',
#  'you,',
#  'they',
#  'belong',
#  'you.',
#  'your',
#  'thoughts,',
#  'thoughts.',
#  'their',
#  'souls,',
#  'of',
#  'tomorrow,',
#  'not',
#  'even',
#  'dreams.',
#  'seek',
#  'not',
#  'with',
#  'yesterday.',
#  'your',
#  'children',
#  'sent',
#  'forth.',
#  'path',
#  'of',
#  'with',
#  'His',
#  'swift',
#  'far.',
#  'be',
#  'for',
#  'gladness;',
#  'that',
#  'flies,',
#  'is',
#  'stable.',
#  '*****',
#  'of',
#  '_Giving_.',
#  'answered:',
#  'of',
#  'your',
#  'possessions.',
#  'you',
#  'truly',
#  'give.',
#  'things',
#  'you',
#  'need',
#  'them',
#  'tomorrow?',
#  'bring',
#  'to',
#  'bones',
#  'in',
#  'pilgrims',
#  'city?',
#  'need',
#  'itself?',
#  'is',
#  'full,',
#  'unquenchable?',
#  'give',
#  'it',
#  'hidden',
#  'desire',
#  'unwholesome.',
#  'give',
#  'all.',
#  'is',
#  'never',
#  'empty.',
#  'that',
#  'reward.',
#  'pain,',
#  'baptism.',
#  'know',
#  'not',
#  'seek',
#  'joy,',
#  'of',
#  'virtue;',
#  'myrtle',
#  'breathes',
#  'space.',
#  'God',
#  'speaks,',
#  'He',
#  'smiles',
#  'earth.',
#  '0039]',
#  'it',
#  'is',
#  'through',
#  'understanding;',
#  'for',
#  'greater',
#  'than',
#  'giving.',
#  'withhold?',
#  'given;',
#  'season',
#  'of',
#  'your',
#  'inheritors’.',
#  'only',
#  'to',
#  'deserving.”',
#  'so,',
#  'nor',
#  'pasture.',
#  'to',
#  'withhold',
#  'perish.',
#  'his',
#  'days',
#  'all',
#  'else',
#  'you.',
#  'from',
#  'his',
#  'cup',
#  'stream.',
#  'be,',
#  'than',
#  'courage',
#  'of',
#  'receiving?',
#  'rend',
#  'pride,',
#  'that',
#  'their',
#  'unabashed?',
#  'to',
#  'be',
#  'giving.',
#  'unto',
#  'life--while',
#  'giver,',
#  'witness.',
#  'are',
#  'all',
#  'of',
#  'gratitude,',
#  'upon',
#  'yourself',
#  'gives.',
#  'on',
#  'his',
#  'wings;',
#  'is',
#  'ito',
#  'freehearted',
#  'God',
#  'for',
#  'father.',
#  '0042]',
#  '*****',
#  'inn,',
#  'Drinking_.',
#  'said:',
#  'fragrance',
#  'air',
#  'plant',
#  'light.',
#  'rob',
#  'to',
#  'quench',
#  'act',
#  'worship,',
#  'on',
#  'which',
#  'of',
#  'forest',
#  'that',
#  'which',
#  'innocent',
#  'in',
#  'man.',
#  'your',
#  'heart,',
#  'too',
#  'am',
#  'consumed.',
#  'into',
#  'my',
#  'mightier',
#  'hand.',
#  'but',
#  'heaven.”',
#  'your',
#  'teeth,',
#  'heart,',
#  'body,',
#  'shall',
#  'blossom',
#  'heart,',
#  'breath,',
#  'And',
#  'through',
#  'all',
#  'seasons.”',
#  'gather',
#  'winepress,',
#  'heart,',
#  'shall',
#  'be',
#  'winepress,',
#  'in',
#  'eternal',
#  'vessels.”',
#  'wine,',
#  'song',
#  'for',
#  'cup;',
#  'remembrance',
#  'for',
#  'winepress.',
#  'Speak',
#  'to',
#  '_Work_.',
#  'saying:',
#  'earth',
#  'earth.',
#  'stranger',
#  'unto',
#  'of',
#  'life’s',
#  'in',
#  'majesty',
#  'infinite.',
#  'through',
#  'whose',
#  'hours',
#  'turns',
#  'music.',
#  'silent,',
#  'in',
#  'unison?',
#  'curse',
#  'misfortune.',
#  'you',
#  'fulfil',
#  'dream,',
#  'was',
#  'born,',
#  'you',
#  'are',
#  'life,',
#  'be',
#  'intimate',
#  'secret.',
#  'affliction',
#  'flesh',
#  'answer',
#  'of',
#  'your',
#  'is',
#  'written.',
#  'is',
#  'darkness,',
#  'echo',
#  'what',
#  'weary.',
#  'darkness',
#  '‘save',
#  'urge,',
#  'is',
#  'knowledge,',
#  'when',
#  'there',
#  'work,',
#  'is',
#  'love;',
#  'bind',
#  'one',
#  'another,',
#  'God.',
#  'love?',
#  'threads',
#  'drawn',
#  'your',
#  'beloved',
#  'cloth.',
#  'affection,',
#  'even',
#  'in',
#  'that',
#  'house.',
#  'reap',
#  'if',
#  'your',
#  'fruit.',
#  'fashion',
#  'with',
#  'spirit,',
#  'dead',
#  'are',
#  'watching.',
#  'if',
#  'speaking',
#  'in',
#  'marble,',
#  'own',
#  'soul',
#  'who',
#  'ploughs',
#  'seizes',
#  'likeness',
#  'who',
#  'makes',
#  'feet.”',
#  'overwakefulness',
#  'wind',
#  'giant',
#  'blades',
#  'grass;',
#  'voice',
#  'made',
#  'sweeter',
#  'loving.',
#  'visible.',
#  'but',
#  'only',
#  'that',
#  'you',
#  'at',
#  'of',
#  'those',
#  'joy.',
#  'indifference,',
#  'you',
#  'but',
#  'half',
#  'hunger.',
#  'grapes,',
#  'in',
#  'as',
#  'angels,',
#  'you',
#  'muffle',
#  'day',
#  'night.',
#  '*****',
#  'of',
#  '_Joy',
#  'Sorrow_.',
#  'answered:',
#  'unmasked.',
#  'your',
#  'laughter',
#  'filled',
#  'with',
#  'tears.',
#  'be?',
#  'your',
#  'being,',
#  'contain.',
#  'very',
#  'potter’s',
#  'oven?',
#  'your',
#  'spirit,',
#  'hollowed',
#  'with',
#  'knives?',
#  'your',
#  'heart',
#  'only',
#  'that',
#  'is',
#  'giving',
#  'joy.',
#  'in',
#  'that',
#  'in',
#  'which',
#  'has',
#  'delight.',
#  'than',
#  'sorrow,”',
#  'is',
#  'greater.”',
#  'are',
#  'inseparable.',
#  'sits',
#  'alone',
#  'remember',
#  'that',
#  'bed.',
#  'scales',
#  'between',
#  'joy.',
#  'at',
#  'standstill',
#  'balanced.',
#  'to',
#  'weigh',
#  'needs',
#  'must',
#  'or',
#  'fall.',
#  '*****',
#  'said,',
#  'Speak',
#  '_Houses_.',
#  'said:',
#  'wilderness',
#  'within',
#  'walls.',
#  'in',
#  'your',
#  'in',
#  'you,',
#  'alone.',
#  'body.',
#  'stillness',
#  'not',
#  'dreamless.',
#  'dream?',
#  'grove',
#  'or',
#  'hilltop?',
#  'houses',
#  'into',
#  'scatter',
#  'them',
#  'meadow.',
#  'you',
#  'through',
#  'vineyards,',
#  'fragrance',
#  'of',
#  'garments.',
#  'be.',
#  'gathered',
#  'you',
#  'fear',
#  'shall',
#  'little',
#  'longer',
#  'separate',
#  'your',
#  'fields.',
#  'what',
#  'have',
#  'it',
#  'you',
#  'doors?',
#  'that',
#  'reveals',
#  'power?',
#  'glimmering',
#  'arches',
#  'mind?',
#  'heart',
#  'from',
#  'stone',
#  'to',
#  'mountain?',
#  'houses?',
#  'lust',
#  'for',
#  'that',
#  'then',
#  'becomes',
#  'master?',
#  'with',
#  'hook',
#  'your',
#  'larger',
#  'desires.',
#  'heart',
#  'is',
#  'iron.',
#  'by',
#  'your',
#  'flesh.',
#  'lays',
#  'fragile',
#  'vessels.',
#  'murders',
#  'walks',
#  'grinning',
#  'funeral.',
#  'restless',
#  'in',
#  'nor',
#  'tamed.',
#  'mast.',
#  'that',
#  'that',
#  'guards',
#  'eye.',
#  'you',
#  'may',
#  'your',
#  'heads',
#  'ceiling,',
#  'walls',
#  'should',
#  'down.',
#  'dead',
#  'living.',
#  'splendour,',
#  'hold',
#  'your',
#  'longing.',
#  'you',
#  'abides',
#  'whose',
#  'door',
#  'whose',
#  'windows',
#  'silences',
#  'of',
#  'night.',
#  '*****',
#  'of',
#  '_Clothes_.',
#  'answered:',
#  'your',
#  'beauty,',
#  'unbeautiful.',
#  'freedom',
#  'them',
#  'chain.',
#  'less',
#  'of',
#  'raiment,',
#  'sunlight',
#  'wind.',
#  'wind',
#  'who',
#  'wear.”',
#  'wind,',
#  'softening',
#  'thread.',
#  'in',
#  'modesty',
#  'is',
#  'unclean.',
#  'more,',
#  'what',
#  'fouling',
#  'mind?',
#  'delights',
#  'to',
#  'winds',
#  'long',
#  'hair.',
#  '*****',
#  'of',
#  '_Buying',
#  'Selling_.',
#  'said:',
#  'you',
#  'how',
#  'to',
#  'hands.',
#  'earth',
#  'be',
#  'satisfied.',
#  'kindly',
#  'to',
#  'greed',
#  'hunger.',
#  'of',
#  'meet',
#  'gatherers',
#  'spices,--',
#  'earth,',
#  'sanctify',
#  'reckoning',
#  'that',
#  'take',
#  'part',
#  'would',
#  'sell',
#  'labour.',
#  'say,',
#  'with',
#  'our',
#  'your',
#  'net;',
#  'be',
#  'bountiful',
#  ...]

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
   
    word_list = ['and', 'the', 'a', 'an']
    
    # your code here

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # your code here
    return a + " " + b

# %%
# your code here
reduce(concat_space, prophet_filter)
# Out:
# 'beloved, own day, city of to return of his birth. seventh day he climbed walls his ship mist. flung open, sea. And silences soul. sadness came his heart: without sorrow? spirit spent within nights depart from without regret? scattered many are walk naked cannot withdraw ache. this day, own hands. me, but with thirst. longer. her calls embark. in crystallize mould. is here. I? Alone must ether. eagle sun. hill, sea, harbour, mariners, land. he said: of tides, dreams. And which is dream. with sails wind. in this look cast backward, seafarer you, vast mother, river stream, stream make, glade, boundless ocean. men their vineyards city gates. his name, field telling his ship. himself: of gathering? in truth dawn? has left to him his winepress? tree may gather them? fountain cups? mighty may breath may me? what treasure may confidence? what fields in what seasons? lift flame that therein. lantern, fill it also. much in deeper secret. 0020] all they were one voice. forth said: us. our twilight, us dreams dream. nor dearly beloved. for your face. said unto him: us now, our midst memory. spirit, light upon faces. speechless was been veiled. would you. knows not of separation. him. But bent his saw his breast. towards temple. woman she was seeress. exceeding tenderness, first sought had been saying: uttermost, distances ship. must needs go. of your place of love would hold you. that you your truth. children, it shall perish. with our you have laughter sleep. ourselves, shown you death. answered, now moving souls? ***** of _Love_. upon stillness upon he said: him, steep. to him, his pinions you. in him, dreams as garden. shall he your growth pruning. branches that sun, shake earth. unto himself. naked. your husks. whiteness. pliant; sacred fire, bread for feast. you that your heart, fragment heart. only love’s pleasure, you cover of love’s threshing-floor, you shall your laughter, your tears. takes naught itself. be possessed; love. “God is in God.” course of you worthy, course. fulfil itself. have desires, desires: that sings tenderness. understanding of love; joyfully. give loving; meditate love’s ecstacy; with gratitude; for of praise lips. 0029] ***** said, And master? saying: you shall forevermore. white wings days. silent God. your togetherness, dance between you. of love: between souls. from one cup. eat not dance let each alone, alone though music. each other’s keeping. contain your hearts. near together: stand apart, grow not shadow. 0032] ***** babe against of _Children_. said: children. of Life’s itself. you, they belong you. your thoughts, thoughts. their souls, of tomorrow, not even dreams. seek not with yesterday. your children sent forth. path of with His swift far. be for gladness; that flies, is stable. ***** of _Giving_. answered: of your possessions. you truly give. things you need them tomorrow? bring to bones in pilgrims city? need itself? is full, unquenchable? give it hidden desire unwholesome. give all. is never empty. that reward. pain, baptism. know not seek joy, of virtue; myrtle breathes space. God speaks, He smiles earth. 0039] it is through understanding; for greater than giving. withhold? given; season of your inheritors’. only to deserving.” so, nor pasture. to withhold perish. his days all else you. from his cup stream. be, than courage of receiving? rend pride, that their unabashed? to be giving. unto life--while giver, witness. are all of gratitude, upon yourself gives. on his wings; is ito freehearted God for father. 0042] ***** inn, Drinking_. said: fragrance air plant light. rob to quench act worship, on which of forest that which innocent in man. your heart, too am consumed. into my mightier hand. but heaven.” your teeth, heart, body, shall blossom heart, breath, And through all seasons.” gather winepress, heart, shall be winepress, in eternal vessels.” wine, song for cup; remembrance for winepress. Speak to _Work_. saying: earth earth. stranger unto of life’s in majesty infinite. through whose hou ...

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
# your code here
prophet_string = reduce(concat_space, prophet_filter)
prophet_string
# Out:
# 'beloved, own day, city of to return of his birth. seventh day he climbed walls his ship mist. flung open, sea. And silences soul. sadness came his heart: without sorrow? spirit spent within nights depart from without regret? scattered many are walk naked cannot withdraw ache. this day, own hands. me, but with thirst. longer. her calls embark. in crystallize mould. is here. I? Alone must ether. eagle sun. hill, sea, harbour, mariners, land. he said: of tides, dreams. And which is dream. with sails wind. in this look cast backward, seafarer you, vast mother, river stream, stream make, glade, boundless ocean. men their vineyards city gates. his name, field telling his ship. himself: of gathering? in truth dawn? has left to him his winepress? tree may gather them? fountain cups? mighty may breath may me? what treasure may confidence? what fields in what seasons? lift flame that therein. lantern, fill it also. much in deeper secret. 0020] all they were one voice. forth said: us. our twilight, us dreams dream. nor dearly beloved. for your face. said unto him: us now, our midst memory. spirit, light upon faces. speechless was been veiled. would you. knows not of separation. him. But bent his saw his breast. towards temple. woman she was seeress. exceeding tenderness, first sought had been saying: uttermost, distances ship. must needs go. of your place of love would hold you. that you your truth. children, it shall perish. with our you have laughter sleep. ourselves, shown you death. answered, now moving souls? ***** of _Love_. upon stillness upon he said: him, steep. to him, his pinions you. in him, dreams as garden. shall he your growth pruning. branches that sun, shake earth. unto himself. naked. your husks. whiteness. pliant; sacred fire, bread for feast. you that your heart, fragment heart. only love’s pleasure, you cover of love’s threshing-floor, you shall your laughter, your tears. takes naught itself. be possessed; love. “God is in God.” course of you worthy, course. fulfil itself. have desires, desires: that sings tenderness. understanding of love; joyfully. give loving; meditate love’s ecstacy; with gratitude; for of praise lips. 0029] ***** said, And master? saying: you shall forevermore. white wings days. silent God. your togetherness, dance between you. of love: between souls. from one cup. eat not dance let each alone, alone though music. each other’s keeping. contain your hearts. near together: stand apart, grow not shadow. 0032] ***** babe against of _Children_. said: children. of Life’s itself. you, they belong you. your thoughts, thoughts. their souls, of tomorrow, not even dreams. seek not with yesterday. your children sent forth. path of with His swift far. be for gladness; that flies, is stable. ***** of _Giving_. answered: of your possessions. you truly give. things you need them tomorrow? bring to bones in pilgrims city? need itself? is full, unquenchable? give it hidden desire unwholesome. give all. is never empty. that reward. pain, baptism. know not seek joy, of virtue; myrtle breathes space. God speaks, He smiles earth. 0039] it is through understanding; for greater than giving. withhold? given; season of your inheritors’. only to deserving.” so, nor pasture. to withhold perish. his days all else you. from his cup stream. be, than courage of receiving? rend pride, that their unabashed? to be giving. unto life--while giver, witness. are all of gratitude, upon yourself gives. on his wings; is ito freehearted God for father. 0042] ***** inn, Drinking_. said: fragrance air plant light. rob to quench act worship, on which of forest that which innocent in man. your heart, too am consumed. into my mightier hand. but heaven.” your teeth, heart, body, shall blossom heart, breath, And through all seasons.” gather winepress, heart, shall be winepress, in eternal vessels.” wine, song for cup; remembrance for winepress. Speak to _Work_. saying: earth earth. stranger unto of life’s in majesty infinite. through whose hou ...
